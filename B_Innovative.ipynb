# %% [markdown]
# # Intutite Deep Learning Class - B_Innovative classes

# %% [markdown]
# In this we will be understanding the concepts. It is more practical. But we wont be using any framework for that
# The contents are -
#
# 1.

# %% [markdown]
# 1. What is machin learning?
# ans. A field of study that gives computer the ability to learn without being explicitly programmed - Arthur Sammuel
# Mostly general as the name implies, ML is a subfield of computer science wherein machines learn to perform tasks for which they were not explicitly programmed.
#
# Direct or indirect imitation after observing pattern
#
# We know there are two type of ML supervised and unsupervised. They can be further divided into parametric and non-parametric
#
# 2. What is difference parametric and non-parametric algorithm?
# ans. A parametric is characterized by having a fixed number of parameters whereas a non-parametric model's number of parameters is infinite(determined by data)
#
# Parametric - A learning model that summarizes data with a set of parameters of fixed size (independent of the number of training examples) is called a parametric model. No matter how much data you throw at a parametric model, it won’t change its mind about how many parameters it needs.
#
#
# The algorithms involve two steps:
#
# Select a form for the function.
# Learn the coefficients for the function from the training data.
#
#
# Some more examples of parametric machine learning algorithms include:
#
# Logistic Regression
# Linear Discriminant Analysis
# Perceptron
# Naive Bayes
# Simple Neural Networks
#
#
# non parametric - Nonparametric methods are good when you have a lot of data and no prior knowledge, and when you don’t want to worry too much about choosing just the right features
#
# Some more examples of popular nonparametric machine learning algorithms are:
#
# k-Nearest Neighbors
# Decision Trees like CART and C4.5
# Support Vector Machines

# %% [markdown]
# # Introduction to Neural Prediction Forward Propagation
# # 1. A Simple network Making a Prediction
# # 2. What is neural network and what does it do?
# # 3. Making a prediction with multiple inputs
# # 4. Making a prediction with multiple outputs
# # 5. Predicting on Predictions

# %%
#####A SEC #####
So the basic actions are predict compare and learn. We will try to dive deep into Predict

# %%
import cv2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('DATa\\secA1.png')

# %%
img =cv2.resize(img,(1300,800))

# %%
plt.imshow(img)

# %%
img = cv2.imread('DATa\\secA2.png')
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
 ## This is your plot
plt.imshow(img)

# %% [markdown]
# We just made the first neural network and used it to predict.
# So for now what is neural network?
# For now its one or more weights which we can multiply our input data to make prediction
# So the question that comes in our mind are -
#
# What is input data?
#
# What is prediction?
#
# Is this prediction always right?
#
# How does the network learn?

# %%
import numpy as np
weights = np.array([0.1, 0.2, 0])
def neural_network(input, weights):
    pred = input.dot(weights)
    return pred
    
strike_rates =  np.array([8.5, 9.5, 9.9, 9.0])
wlrec = np.array([0.65, 0.8, 0.8, 0.9])
nfans = np.array([1.2, 1.3, 0.5, 1.0])



input = np.array([strike_rates[0],wlrec[0],nfans[0]])
pred = neural_network(input,weights)

print(pred)
# Out:
# 0.9800000000000001

# %% [markdown]
# What every neural network does?
# It accepts an input variable as information and a weight variable as knowledge and outputs a prediction
#
#
# Another way to think about a neural network's weight is as a measure of sensitivity between input of the network
# and its prediction

# %%
# Instead of predicting just 
# whether the team won or lost, 
# now we're also predicting whether
# they are happy/sad AND the percentage
# of the team that is hurt. We are
# making this prediction using only
# the current win/loss record.

def ele_mul(number,vector):
    output = [0,0,0]
    assert(len(output) == len(vector))
    for i in range(len(vector)):
        output[i] = number * vector[i]
    return output

weights = [0.3, 0.2, 0.9] 

def neural_network(input, weights):
    pred = ele_mul(input,weights)
    return pred
    
wlrec = [0.65, 0.8, 0.8, 0.9]
input = wlrec[0]
pred = neural_network(input,weights)

print(pred)
# Out:
# [0.195, 0.13, 0.5850000000000001]

# %% [markdown]
# So now we can see we are providing vectors instead of single number. Well a vector is nothing other than a list of numbers.
# here inp and wts are vector. A list of vectors is called matrix

# %%
            #toes %win #fans
weights = [ [0.1, 0.1, -0.3], #hurt?
            [0.1, 0.2, 0.0], #win?
            [0.0, 1.3, 0.1] ] #sad?
#toes = total striking rate
def w_sum(a,b):
    assert(len(a) == len(b))
    output = 0
    for i in range(len(a)):
        output += (a[i] * b[i])
    return output

def vect_mat_mul(vect,matrix):
    assert(len(vect) == len(matrix))
    output = [0,0,0]
    for i in range(len(vect)):
        output[i] = w_sum(vect,matrix[i])
    return output

def neural_network(input, weights):
    pred = vect_mat_mul(input,weights)
    return pred

# This dataset is the current
# status at the beginning of
# each game for the first 4 games
# in a season.

# toes = current number of toes
# wlrec = current games won (percent)
# nfans = fan count (in millions)

toes =  [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65,0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

# Input corresponds to every entry
# for the first game of the season.

input = [toes[0],wlrec[0],nfans[0]]
pred = neural_network(input,weights)

print(pred)
# Out:
# [0.555, 0.9800000000000001, 0.9650000000000001]

# %%
a= np.array([0, 1, 0, 1])
b = np.array([1, 0, 1, 0])
c = np.array([0,1,1,0])

# %%
np.dot(a,b)
# Out:
# 0

# %%
np.dot(a,c)
# Out:
# 1

# %%
well loosely stated a dot product fives us a notion of similarity between two vectors. Very rought speaking, 
it means that our network gives high score of our inputs based on how similar to our weights. We cannot shuffle
our weights

# %% [markdown]
# # SEC B ##
# Do neural networks make accurate predictions?
# Why messure error?
# Hot and cold learning?
# calculating both direction and amount from error
# Gradient Descent
# Learning is just reducing error
# Derivatives and how to use them to learn
# Divergence and Alpha

# %% [markdown]
# "The only relevant test of the valadity of hypothesis is comaparison of prediction with experience" - Milton Friedman

# %% [markdown]
# Well this section is about compare and learn. We have already learnt about predict in previous section.
#
# 1. what we understand by compare?
# 2. What u understand by actually learn?

# %%
knob_weight = 0.5
input = 0.5
goal_pred = 0.8

pred = input * knob_weight
error = (pred - goal_pred) ** 2
# forces the raw error to be positive by squaring 
print(error)

# The error is simply telling our network how much we missed
# Out:
# 0.30250000000000005

# %% [markdown]
# ---->Question time?
# 1. What is goal_pred variable?
# 2. Why is the error squarred?
# 3. Doesn't squaring make big errors(>1) bigger and smaller(<1) errors smaller?

# %%
# At the en learning is about really one thing, adjusting wt know either up or down that our error reduces


# 1) An Empty Network

weight = 0.1 
lr = 0.01

def neural_network(input, weight):
    prediction = input * weight
    return prediction


# 2) PREDICT: Making A Prediction And Evaluating Error

number_of_toes = [8.5]
win_or_lose_binary = [1] #(won!!!)

input = number_of_toes[0]
true = win_or_lose_binary[0]

pred = neural_network(input,weight)
error = (pred - true) ** 2
print(error)
# Out:
# 0.022499999999999975

# %%
#hot and cold learning - wiggling our weights to see which direction reduces the error the most, moving our wts in that direction,
# and repeating until the error gets to 0
# 3) COMPARE: Making A Prediction With a *Higher* Weight And Evaluating Error

weight = 0.1 

def neural_network(input, weight):
    prediction = input * weight
    return prediction

number_of_toes = [8.5]
win_or_lose_binary = [1] #(won!!!)

input = number_of_toes[0]
true = win_or_lose_binary[0]

lr = 0.01
p_up = neural_network(input,weight+lr)
e_up = (p_up - true) ** 2
print(e_up)
# Out:
# 0.004224999999999993

# %%
# 4) COMPARE: Making A Prediction With a *Lower* Weight And Evaluating Error

weight = 0.1 

def neural_network(input, weight):
    prediction = input * weight
    return prediction

number_of_toes = [8.5]
win_or_lose_binary = [1] #(won!!!)

input = number_of_toes[0]
true = win_or_lose_binary[0]

lr = 0.01
p_dn = neural_network(input,weight-lr)
e_dn = (p_dn - true) ** 2
print(e_dn)
# Out:
# 0.05522499999999994

# %% [markdown]
# put emphasis on
# 1. step amount
# 2. iterations
# 3. try up and try down

# %%
weight = 0.5
input = 0.5
goal_prediction = 0.8

step_amount = 0.001


for iteration in range(1101):

    prediction = input * weight
    error = (prediction - goal_prediction) ** 2

    print("Error:" + str(error) + " Prediction:" + str(prediction))
    
    up_prediction = input * (weight + step_amount)
    up_error = (goal_prediction - up_prediction) ** 2

    down_prediction = input * (weight - step_amount)
    down_error = (goal_prediction - down_prediction) ** 2

    if(down_error < up_error):
        weight = weight - step_amount
        
    if(down_error > up_error):
        weight = weight + step_amount
# Out:
# Error:0.30250000000000005 Prediction:0.25
# Error:0.3019502500000001 Prediction:0.2505
# Error:0.30140100000000003 Prediction:0.251
# Error:0.30085225 Prediction:0.2515
# Error:0.30030400000000007 Prediction:0.252
# Error:0.2997562500000001 Prediction:0.2525
# Error:0.29920900000000006 Prediction:0.253
# Error:0.29866224999999996 Prediction:0.2535
# Error:0.29811600000000005 Prediction:0.254
# Error:0.2975702500000001 Prediction:0.2545
# Error:0.29702500000000004 Prediction:0.255
# Error:0.29648025 Prediction:0.2555
# Error:0.29593600000000003 Prediction:0.256
# Error:0.2953922500000001 Prediction:0.2565
# Error:0.294849 Prediction:0.257
# Error:0.29430625 Prediction:0.2575
# Error:0.293764 Prediction:0.258
# Error:0.2932222500000001 Prediction:0.2585
# Error:0.292681 Prediction:0.259
# Error:0.29214025 Prediction:0.2595
# Error:0.2916 Prediction:0.26
# Error:0.2910602500000001 Prediction:0.2605
# Error:0.29052100000000003 Prediction:0.261
# Error:0.28998225 Prediction:0.2615
# ...

# %%
What are the problems with hot and cold learning?
1. Its inefficient
2. sometimes its impossible to predict the exact goal prediction
---->

# pred = 0 my inp is 0
# error = 6 , goa_pre = 6
wt updating is happening, error = 6


So what we had a way of computing both direction and amount for each weight without having to repeatedly make pred?

# %%
weight = 0.5
goal_pred = 0.8
input = 0.5

for iteration in range(20):
    pred = input * weight
    error = (pred - goal_pred) ** 2
    direction_and_amount = (pred - goal_pred) * input
    # direction_and_amount = direction_and_amount * alpha 
    weight = weight - direction_and_amount

    print("Error:" + str(error) + " Prediction:" + str(pred))
# Out:
# Error:0.30250000000000005 Prediction:0.25
# Error:0.17015625000000004 Prediction:0.3875
# Error:0.095712890625 Prediction:0.49062500000000003
# Error:0.05383850097656251 Prediction:0.56796875
# Error:0.03028415679931642 Prediction:0.6259765625
# Error:0.0170348381996155 Prediction:0.669482421875
# Error:0.00958209648728372 Prediction:0.70211181640625
# Error:0.005389929274097089 Prediction:0.7265838623046875
# Error:0.0030318352166796153 Prediction:0.7449378967285156
# Error:0.0017054073093822882 Prediction:0.7587034225463867
# Error:0.0009592916115275371 Prediction:0.76902756690979
# Error:0.0005396015314842384 Prediction:0.7767706751823426
# Error:0.000303525861459885 Prediction:0.7825780063867569
# Error:0.00017073329707118678 Prediction:0.7869335047900676
# Error:9.603747960254256e-05 Prediction:0.7902001285925507
# Error:5.402108227642978e-05 Prediction:0.7926500964444131
# Error:3.038685878049206e-05 Prediction:0.7944875723333098
# ...

# %% [markdown]
# What u see is gradient descent. helps us calc amount and direction to regularize wt to reduce error
#
# 1. What is direction_and_amount?
# ans. It represents how we want to change our weight. The 'pure error' (pred- goal_pred). and when we multiply raw error with input , this number represents "the raw direction and  amount we missed". Multiplying with inputs performs scaling, negative reversal and stopping
#
# 2. What is pure error?
# ans. pred-goal_pred, raw direction and amount
#
# 3. What is scaling, negative reversal and stopping?
# ans. These three attributes have the combined have the combined affect of translating our pure error into the absolute amount that we want to change our weight.
#
# 4. What is stopping?
# ans. if our input is also 0,then it will force our direction_and_amount to also be 0.
#
# 5. What is negative reversal?
# ans. if input is negative will reverse the sign of our direction_and_amount
#
# 6. What is scaling?
# ans. Well logically it means that if our input was big, our weight update should also be big.cons- can go out of control
# sol - alpha

# %%
weight = 0.1 
alpha = 0.01

def neural_network(input, weight):
    prediction = input * weight
    return prediction

# 2) PREDICT: Making A Prediction And Evaluating Error

number_of_toes = [8.5]
win_or_lose_binary = [1] # (won!!!)

input = number_of_toes[0]
goal_pred = win_or_lose_binary[0]

pred = neural_network(input,weight)
error = (pred - goal_pred) ** 2

# 3) COMPARE: Calculating "Node Delta" and Putting it on the Output Node

delta = pred - goal_pred

# 4) LEARN: Calculating "Weight Delta" and Putting it on the Weight

weight_delta = input * delta

# 5) LEARN: Updating the Weight

alpha = 0.01 # fixed before training
weight -= weight_delta * alpha

weight, goal_pred, input = (0.0, 0.8, 0.5)

for iteration in range(4):
    
    pred = input * weight
    error = (pred - goal_pred) ** 2
    delta = pred - goal_pred
    weight_delta = delta * input
    weight = weight - weight_delta
    print("Error:" + str(error) + " Prediction:" + str(pred))
# Out:
# Error:0.6400000000000001 Prediction:0.0
# Error:0.3600000000000001 Prediction:0.2
# Error:0.2025 Prediction:0.35000000000000003
# Error:0.11390625000000001 Prediction:0.4625

# %% [markdown]
# So the golden method of learning is adjusting each weight in the correct direction and by the correct amount
# so the our error reduces to 0
#
# Well the secret is for any input and goal_pred, there is an exact relationship defined between our error and weight
# error = ((2 * 4)-8) ** 2
# Does it remind of something?

# %%
weight = 0.5
goal_pred = 0.8
input = 0.5

for iteration in range(20):
    pred = input * weight
    error = (pred - goal_pred) ** 2
    direction_and_amount = (pred - goal_pred) * input
    weight = weight - direction_and_amount

    print("Error:" + str(error) + " Prediction:" + str(pred))
# Out:
# Error:0.30250000000000005 Prediction:0.25
# Error:0.17015625000000004 Prediction:0.3875
# Error:0.095712890625 Prediction:0.49062500000000003
# Error:0.05383850097656251 Prediction:0.56796875
# Error:0.03028415679931642 Prediction:0.6259765625
# Error:0.0170348381996155 Prediction:0.669482421875
# Error:0.00958209648728372 Prediction:0.70211181640625
# Error:0.005389929274097089 Prediction:0.7265838623046875
# Error:0.0030318352166796153 Prediction:0.7449378967285156
# Error:0.0017054073093822882 Prediction:0.7587034225463867
# Error:0.0009592916115275371 Prediction:0.76902756690979
# Error:0.0005396015314842384 Prediction:0.7767706751823426
# Error:0.000303525861459885 Prediction:0.7825780063867569
# Error:0.00017073329707118678 Prediction:0.7869335047900676
# Error:9.603747960254256e-05 Prediction:0.7902001285925507
# Error:5.402108227642978e-05 Prediction:0.7926500964444131
# Error:3.038685878049206e-05 Prediction:0.7944875723333098
# ...

# %%
img = cv2.imread('DATa\\secB1.png')
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
 ## This is your plot
plt.imshow(img)

# %% [markdown]
# Key takeaways - The slope points to the bottom of the bowl(lowest error) no matter where you are in the bowl. We can use this slope
# to help our neural network to reduce the error
#
# Now we can see sensitivity is really just another name for direction and amount
#
# --->

# %% [markdown]
# Wow we just defined derivative. Thus given a function, the derivative represnts the direction and the amount that one
# variable changes if you change the other variable
#
# Other way to explain derivative that it is the slope at a point on a line or curve

# %%
weight = 0.5
goal_pred = 0.8
input = 2
alpha = 0.1

for iteration in range(20):
    pred  = input * weight
    error = (pred - goal_pred) ** 2
    # pred - goal_pred is delta
    derivative = input * (pred - goal_pred)
    weight = weight - (alpha * derivative)
    
    print("Error:" + str(error) + " Prediction:" + str(pred))
# Out:
# Error:0.03999999999999998 Prediction:1.0
# Error:0.0144 Prediction:0.92
# Error:0.005183999999999993 Prediction:0.872
# Error:0.0018662400000000014 Prediction:0.8432000000000001
# Error:0.0006718464000000028 Prediction:0.8259200000000001
# Error:0.00024186470400000033 Prediction:0.815552
# Error:8.70712934399997e-05 Prediction:0.8093312
# Error:3.134566563839939e-05 Prediction:0.80559872
# Error:1.1284439629823931e-05 Prediction:0.803359232
# Error:4.062398266736526e-06 Prediction:0.8020155392
# Error:1.4624633760252567e-06 Prediction:0.8012093235200001
# Error:5.264868153690924e-07 Prediction:0.8007255941120001
# Error:1.8953525353291194e-07 Prediction:0.8004353564672001
# Error:6.82326912718715e-08 Prediction:0.8002612138803201
# Error:2.456376885786678e-08 Prediction:0.8001567283281921
# Error:8.842956788836216e-09 Prediction:0.8000940369969153
# Error:3.1834644439835434e-09 Prediction:0.8000564221981492
# Error:1.1460471998340758e-09 Prediction:0.8000338533188895
# ...

# %% [markdown]
# So what we understood-
# The derivative defines the relationship between each weight and how much we missed. In other words, it tells how much
# changing a weight contributes to the error.

# %% [markdown]
# to avoid overcorrectness , divergence we use alpha
# --->

# %%
img = cv2.imread('DATa\\secB2.png')

plt.figure(figsize=(20,10))
 ## This is your plot
plt.imshow(img)

# %%
# delta
# delta_amount * alpha
alpha = 0.01
